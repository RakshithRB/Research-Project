# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#load dataset
AAPL = pd.read_csv("/content/drive/MyDrive/Datasets/AAPL.csv")
ALPH = pd.read_csv("/content/drive/MyDrive/Datasets/ALPH.csv")
AMZN = pd.read_csv("/content/drive/MyDrive/Datasets/AMZN.csv")
TSLA = pd.read_csv("/content/drive/MyDrive/Datasets/TSLA.csv")
MSFT = pd.read_csv("/content/drive/MyDrive/Datasets/MSFT.csv")

# %% [markdown]
# # Dataset Preprocessing

# %% [markdown]
# ***APPLE***

# %%
AAPL.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2017-03-27  34.847500  35.305000  34.654999  35.220001  33.204529
# 1 2017-03-28  35.227501  36.009998  35.154999  35.950001  33.892750
# 2 2017-03-29  35.919998  36.122501  35.797501  36.029999  33.968163
# 3 2017-03-30  36.047501  36.125000  35.875000  35.982498  33.923397
# 4 2017-03-31  35.930000  36.067501  35.752499  35.915001  33.859749
#
#         Volume
# 0   94300400.0
# 1  133499200.0
# 2  116760000.0
# 3   84829200.0
# 4   78646800.0

# %%
AAPL.dropna(inplace = True)
AAPL["Date"] = pd.to_datetime(AAPL["Date"]) #Change Dtype of Columns
AAPL["Volume"] = AAPL["Volume"].astype(str).str.replace(',', '')
AAPL = AAPL.astype({"Open": float, "Volume": float})
AAPL = AAPL.sort_values(by = 'Date', ignore_index = True)
#display stats
AAPL.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean     80.765616    81.675421    79.896640    80.829603    79.520100
# std      43.877034    44.428943    43.328743    43.906827    44.323611
# min      34.847500    35.305000    34.654999    35.169998    33.157394
# 25%      43.777500    44.112502    43.567501    43.822501    42.210426
# 50%      56.557499    57.064999    56.005001    56.602501    54.857216
# 75%     123.245003   124.744999   121.229999   122.970001   122.031777
# max     182.630005   182.940002   179.119995   182.009995   181.511703
#
#              Volume
# count  1.259000e+03
# mean   1.203249e+08
# std    5.543372e+07
# min    4.100000e+07
# 25%    8.358420e+07
# 50%    1.054256e+08
# 75%    1.401866e+08
# max    4.265100e+08

# %% [markdown]
# ***Alphabet (Google)***

# %%
ALPH.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-03-27  806.950012  821.630005  803.369995  819.510010  819.510010
# 1  2017-03-28  820.409973  825.989990  814.026978  820.919983  820.919983
# 2  2017-03-29  825.000000  832.765015  822.380005  831.409973  831.409973
# 3  2017-03-30  833.500000  833.679993  829.000000  831.500000  831.500000
# 4  2017-03-31  828.969971  831.640015  827.390015  829.559998  829.559998
#
#     Volume
# 0  1894300
# 1  1620500
# 2  1786300
# 3  1055300
# 4  1401900

# %%
ALPH.dropna(inplace = True)
ALPH["Date"] = pd.to_datetime(ALPH["Date"])
ALPH["Volume"] = ALPH["Volume"].astype(str).str.replace(',', '')
ALPH = ALPH.astype({"Open": float, "Volume": float})
ALPH = ALPH.sort_values(by = 'Date', ignore_index = True)
ALPH.describe() #display stats
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean   1528.424091  1543.981775  1513.650365  1529.309368  1529.309368
# std     634.445850   640.377357   627.939326   634.049661   634.049661
# min     806.950012   821.630005   803.369995   819.510010   819.510010
# 25%    1081.215027  1093.119995  1068.225037  1080.940002  1080.940002
# 50%    1226.319946  1235.609985  1213.739990  1225.089966  1225.089966
# 75%    1772.885010  1789.564026  1756.084961  1770.790039  1770.790039
# max    3037.270020  3042.000000  2997.750000  3014.179932  3014.179932
#
#              Volume
# count  1.259000e+03
# mean   1.564350e+06
# std    6.926801e+05
# min    3.468000e+05
# 25%    1.125600e+06
# 50%    1.393000e+06
# 75%    1.778850e+06
# max    6.207000e+06

# %% [markdown]
# ***Amazon***

# %%
AMZN.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-03-27  838.070007  850.299988  833.500000  846.820007  846.820007
# 1  2017-03-28  851.750000  858.460022  850.099976  856.000000  856.000000
# 2  2017-03-29  859.049988  876.440002  859.020020  874.320007  874.320007
# 3  2017-03-30  874.950012  877.059998  871.659973  876.340027  876.340027
# 4  2017-03-31  877.000000  890.349976  876.650024  886.539978  886.539978
#
#     Volume
# 0  2755800
# 1  3041600
# 2  4485800
# 3  2762700
# 4  3957600

# %%
AMZN.dropna(inplace = True)
AMZN["Date"] = pd.to_datetime(AMZN["Date"])
AMZN["Volume"] = AMZN["Volume"].astype(str).str.replace(',', '')
AMZN = AMZN.astype({"Open": float, "Volume": float})
AMZN = AMZN.sort_values(by = 'Date', ignore_index = True)
AMZN.describe() #display stats
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean   2188.935442  2212.533564  2162.431272  2187.835258  2187.835258
# std     858.254163   868.823699   846.700119   857.109132   857.109132
# min     838.070007   850.299988   833.500000   846.820007   846.820007
# 25%    1600.989990  1615.039978  1587.264954  1599.575012  1599.575012
# 50%    1880.000000  1897.750000  1860.000000  1882.219971  1882.219971
# 75%    3156.739990  3189.599976  3116.359986  3150.890014  3150.890014
# max    3744.000000  3773.080078  3696.790039  3731.409912  3731.409912
#
#              Volume
# count  1.259000e+03
# mean   4.303511e+06
# std    2.060715e+06
# min    8.813000e+05
# 25%    2.915200e+06
# 50%    3.710900e+06
# 75%    5.090450e+06
# max    1.656500e+07

# %% [markdown]
# ***Tesla***

# %%
TSLA.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2017-03-27  52.119999  54.113998  51.950001  54.043999  54.043999  31154000
# 1  2017-03-28  55.403999  56.136002  55.000000  55.490002  55.490002  39938000
# 2  2017-03-29  55.667999  55.919998  55.108002  55.476002  55.476002  18381000
# 3  2017-03-30  55.608002  56.400002  55.442001  55.584000  55.584000  20742000
# 4  2017-03-31  55.745998  55.936001  55.264000  55.660000  55.660000  16473000

# %%
TSLA.dropna(inplace = True)
TSLA["Date"] = pd.to_datetime(TSLA["Date"])
TSLA["Volume"] = TSLA["Volume"].astype(str).str.replace(',', '')
TSLA = TSLA.astype({"Open": float, "Volume": float})
TSLA = TSLA.sort_values(by = 'Date', ignore_index = True)
TSLA.describe() #display stats
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean    289.830046   296.433356   282.823525   290.000036   290.000036
# std     326.436399   334.040067   318.195968   326.497192   326.497192
# min      36.220001    37.335999    35.397999    35.793999    35.793999
# 25%      61.400002    62.524000    60.233999    61.590999    61.590999
# 50%      71.267998    72.638000    70.269997    71.180000    71.180000
# 75%     601.044983   612.174988   582.654999   599.044983   599.044983
# max    1234.410034  1243.489990  1217.000000  1229.910034  1229.910034
#
#              Volume
# count  1.259000e+03
# mean   4.472418e+07
# std    3.008963e+07
# min    9.800600e+06
# 25%    2.522700e+07
# 50%    3.494600e+07
# 75%    5.209225e+07
# max    3.046940e+08

# %% [markdown]
# ***Microsoft***

# %%
MSFT.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2017-03-27  64.629997  65.220001  64.349998  65.099998  60.628651  18614700
# 1  2017-03-28  64.959999  65.470001  64.650002  65.290001  60.805611  20080400
# 2  2017-03-29  65.120003  65.500000  64.949997  65.470001  60.973240  13618400
# 3  2017-03-30  65.419998  65.980003  65.360001  65.709999  61.196766  15122800
# 4  2017-03-31  65.650002  66.190002  65.449997  65.860001  61.336452  21040300

# %%
MSFT.dropna(inplace = True)
MSFT["Date"] = pd.to_datetime(MSFT["Date"])
MSFT["Volume"] = MSFT["Volume"].astype(str).str.replace(',', '')
MSFT = MSFT.astype({"Open": float, "Volume": float})
MSFT = MSFT.sort_values(by = 'Date', ignore_index = True)
MSFT.describe() #display stats
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean    165.251708   166.855354   163.547514   165.299071   161.767731
# std      78.845934    79.638002    78.001377    78.870342    79.851199
# min      64.629997    65.220001    64.349998    64.949997    60.488949
# 25%     100.255001   101.439999    99.259998   100.854999    96.324803
# 50%     139.229996   140.179993   137.020004   138.789993   134.795090
# 75%     221.559998   223.735001   217.900002   221.084999   217.903503
# max     344.619995   349.670013   342.200012   343.109985   341.606384
#
#              Volume
# count  1.259000e+03
# mean   2.918037e+07
# std    1.304737e+07
# min    7.425600e+06
# 25%    2.082570e+07
# 50%    2.588780e+07
# 75%    3.345830e+07
# max    1.112421e+08

# %% [markdown]
# # Exploring Dataset

# %%
Companies = [AAPL, ALPH, AMZN, TSLA, MSFT]
Companies_Title = ["Apple", "Alphabet", "Amazon", "Tesla", "Microsoft"]

# Lets view historical view of the closing prices
plt.figure(figsize=(22, 15))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Adj Close"])
  plt.title(Companies_Title[index])
  plt.ylabel('Adj Close')

# %% [markdown]
# Moving Avg

# %%
Moving_Average_Day = [10, 50]
for Moving_Average in Moving_Average_Day:
  for company in Companies:
    column_name = f'Moving Average for {Moving_Average} days'
    company[column_name] = company["Adj Close"].rolling(Moving_Average).mean()

# %%
plt.figure(figsize=(26, 16))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Adj Close"])
  plt.plot(company["Date"], company["Moving Average for 10 days"])
  plt.plot(company["Date"], company["Moving Average for 50 days"])
  plt.title(Companies_Title[index])
  plt.legend(("Adj. Close", "Moving Average for 10 days", "Moving Average for 50 days"))

# %% [markdown]
# Correlation between diffrent stocks closing price

# %%
# Companies_return contain closing price of all the companies
Companies_returns = pd.DataFrame()
Companies_returns["AAPL"] = AAPL["Adj Close"]
Companies_returns["ALPH"] = ALPH["Adj Close"]
Companies_returns["AMZN"] = AMZN["Adj Close"]
Companies_returns["TSLA"] = TSLA["Adj Close"]
Companies_returns["MSFT"] = MSFT["Adj Close"]
#Companies_returns.head()
Companies_Daily_returns = Companies_returns.pct_change()
#Companies_Daily_returns.head()

# %%
corr = sns.heatmap(Companies_Daily_returns.corr(), annot=True, cmap="BrBG")
corr.set_title('Correlation between the stocks daily returns', fontdict={'fontsize':24}, pad=18);

# %% [markdown]
# I've gathered on daily percentage returns is by comparing the expected return with the standard deviation of the daily returns.

# %%
#risk
Returns = Companies_Daily_returns.dropna()

plt.figure(figsize=(18, 5))
plt.scatter(Returns.mean(), Returns.std())
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(Companies_Title, Returns.mean(), Returns.std()):
    plt.annotate(label, xy = (x, y), xytext = (10, 0), textcoords = 'offset points')

# %% [markdown]
# Tesla has the highest expected returns and the highest risk factor. Alphabet and Microsoft has the lowest expected returns and the lowest risk factor.
